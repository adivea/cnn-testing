# %%
import pandas as pd

# %%
data = pd.read_csv("../results/west/west.csv", index_col=0)

# %%
plt = data["mound_probability"].plot.hist(bins=100, 
                                          figsize=(20,12), 
                                          title="West")

# %%
plt.figure.savefig("west.png", dpi=300)
