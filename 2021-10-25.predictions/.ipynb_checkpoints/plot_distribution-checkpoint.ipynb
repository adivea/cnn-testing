# %%
import pandas as pd

# %%
data = pd.read_csv("east.csv", index_col=0)

# %%
plt = data["mound_probability"].plot.hist(bins=100, 
                                          figsize=(20,12), 
                                          title="East")

# %%
plt.figure.savefig("east.png", dpi=300)
